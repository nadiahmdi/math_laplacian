# %%
import math

def laplacian_integral(mu, b):
    # Calculate the integral of the Laplacian distribution's PDF
    integral = 1
    return integral

# Example usage
mu = 0  # location parameter
b = 1   # scale parameter

integral_value = laplacian_integral(mu, b)
print("Integral value:", integral_value)
# Out:
# Integral value: 1

# %%
import numpy as np
import matplotlib.pyplot as plt

def laplacian_pdf(x, mu, b):
    return (1 / (2 * b)) * np.exp(-np.abs(x - mu) / b)
# Parameters
mu = 0  # location parameter
b = 1   # scale parameter

# Generate x values
x = np.linspace(-10, 10, 500)
# Calculate PDF values
pdf = laplacian_pdf(x, mu, b)

# Plot the graph
plt.figure(figsize=(6,3))
plt.plot(x, pdf,color='green')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Laplacian Distribution (PDF)')
plt.grid(True)
plt.show()
